# %%
matrix=[[1,2,3],
[4,5,6],
[7,8,9]
       ]
print(matrix[0])
# Out:
# [1, 2, 3]

# %%
colors=input("enter column names seperated by comas: ")
color_list = colors.split(",")
print("first color:",color_list[0].strip())
print("last color:",color_list[-1].strip())
# Out:
# enter column names seperated by comas: red,black
# first color: red
# last color: black

# %%
filename=input("Enter the file name:")
extension=filename.split(".")[1]
print("Extension:",extension)
# Out:
# Enter the file name:safeer.pdf
# Extension: pdf

# %%
numbers= input("enter coma seperated numbers:")
num_list=[int (x)for x in numbers.split(",")]
print("list:" ,num_list)
print("sum:",sum(num_list))
# Out:
# enter coma seperated numbers:10,20,30,40
# list: [10, 20, 30, 40]
# sum: 100
