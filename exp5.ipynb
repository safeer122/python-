# %%
#pytho program to get 3rd element and thrid last of a tuple
tuple1=(10,20,30,40,50,60)
print("3rd element :",tuple1[2])
print("3rd elemnt from last:",tuple1[-3])
# Out:
# 3rd element : 30
# 3rd elemnt from last: 40

# %%
#generate a tuple with number accepted from the user
number = input("enter coma-seperated numbers:")

t =tuple(map(int,number.split(',')))
total=sum(t)

average=total/len(t)
print("Tuple:",t)
print("Average:",average)
# Out:
# enter coma-seperated numbers:10,20,30,40,50
# Tuple: (10, 20, 30, 40, 50)
# Average: 30.0
