# %%
#python program to exchange first and last charecter of a sring

string = input("Enter a string: ")

new_string = string[-1] + string[1:-1] + string[0]

print("New string:", new_string)
# Out:
# Enter a string: safeer
# New string: rafees

# %%
#String made of fisrt 2 and last 2
s = input("Enter String:")
result =s[:2]+s[-2:]
print("Result:",result)
# Out:
# Enter String:safeer
# Result: saer

# %%
#swap charecter
s1 = input ("Enter first string :")
s2 = input ("Enter Second string :")
new_s1 =s2[0]+s1[1:]
new_s2=s1[0]+s2[1:]
print(new_s1 + ""+new_s2)
# Out:
# Enter first string :hello
# Enter Second string :world
# wello horld

# %%
#change char to dollar
s= input("Enter a string:")
first=s[0]
new_string=first +s[1:].replace(first,"$")
print("new_strig:",new_string)
# Out:
# Enter a string:onion
# new_strig: oni$n
