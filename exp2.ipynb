# %%
#celsius into farenheat
celsius=float(input("Enter Temperature in celsius"))
fahrenhiet = celsius*9/5+32
print("Temperature in farenhiet:",fahrenhiet)
# Out:
# Enter Temperature in celsius55
# Temperature in farenhiet: 131.0

# %%
#kilometer into miles
km=float(input("Enter Distance in kilometers: "))
miles = km*0.62137
print("Distance in miles:",round(miles,2))
# Out:
# Enter Distance in kilometers: 10
# Distance in miles: 6.21
